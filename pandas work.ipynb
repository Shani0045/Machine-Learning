# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# dt=pd.read_csv("https://bit.ly/imdbratings")
# dt

# %%
# dt.genre.value_counts().plot(kind='bar')
# dt.style.use('dark_background')
# plt.show()

# %%
dts=pd.read_excel('titanic3.xls')
dts
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
dts.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
dts.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
import numpy as np
col=dts.columns
for i in col:
    if dts[i].dtype==object:
        print(i)
# Out:
# name
# sex
# ticket
# cabin
# embarked
# boat
# home.dest

# %%
d=dict.fromkeys(dts['sex'])
for i,j in enumerate(d):
    d[j]=i
d
# Out:
# {'female': 0, 'male': 1}

# %%
# dts['sex']=list(map(d.get,dts['sex']))

# %%
list(map(d.get,dts['name']))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
for i in enumerate('abcde',100):
    print(i)
# Out:
# (100, 'a')
# (101, 'b')
# (102, 'c')
# (103, 'd')
# (104, 'e')

# %%
for i in enumerate('xyz',5):
    print(i)
# Out:
# (5, 'x')
# (6, 'y')
# (7, 'z')

# %%
dts.columns
dts.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
dts.name.unique()
# Out:
# array(['Allen, Miss. Elisabeth Walton', 'Allison, Master. Hudson Trevor',
#        'Allison, Miss. Helen Loraine', ..., 'Zakarian, Mr. Mapriededer',
#        'Zakarian, Mr. Ortin', 'Zimmerman, Mr. Leo'], dtype=object)

# %%
dts.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
dts['sex']
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
# 10        male
# 11      female
# 12      female
# 13      female
# 14        male
# 15        male
# 16        male
# 17      female
# 18      female
# 19        male
# 20        male
# 21      female
# 22        male
# 23      female
# 24      female
# 25        male
# 26        male
# 27      female
# 28      female
# 29        male
#          ...
# 1279    female
# 1280      male
# 1281      male
# 1282      male
# 1283      male
# 1284      male
# 1285      male
# 1286    female
# 1287      male
# 1288      male
# 1289      male
# 1290    female
# 1291      male
# 1292      male
# 1293      male
# 1294      male
# 1295      male
# 1296      male
# 1297      male
# 1298      male
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305    female
# ...

# %%
d=dict.fromkeys(dts['sex'])
for m,k in enumerate(d):
    d[k]=m
d
# Out:
# {'female': 0, 'male': 1}

# %%
list(map(d.get,['male','female','male']))
# Out:
# [1, 0, 1]

# %%
import numpy as np
col=dts.columns

# %%
dts.corr()
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
x=dts.age.agg(['mean','count'])
x
# Out:
# mean       29.881135
# count    1046.000000
# Name: age, dtype: float64

# %%
dts[['sex','fare','age']].set_index(['sex','fare','age']).head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(female, 211.3375, 29.0), (male, 151.55, 0.9167), (female, 151.55, 2.0), (male, 151.55, 30.0), (female, 151.55, 25.0)]

# %%
dts.dropna()
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
dts.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
import matplotlib.pyplot as plt
dts.corr()
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
dts.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
survived
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
# 5       1
# 6       1
# 7       0
# 8       1
# 9       0
# 10      0
# 11      1
# 12      1
# 13      1
# 14      1
# 15      0
# 16      0
# 17      1
# 18      1
# 19      0
# 20      1
# 21      1
# 22      1
# 23      1
# 24      1
# 25      0
# 26      1
# 27      1
# 28      1
# 29      1
#        ..
# 1279    0
# 1280    0
# 1281    0
# 1282    0
# 1283    0
# 1284    0
# 1285    0
# 1286    1
# 1287    0
# 1288    0
# 1289    0
# 1290    1
# 1291    0
# 1292    0
# 1293    0
# 1294    0
# 1295    0
# 1296    0
# 1297    0
# 1298    0
# 1299    0
# 1300    1
# 1301    0
# 1302    0
# 1303    0
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64

# %%
x=dts.survived.value_counts()
plt.xlabel('x-axis')
plt.title('survived data')
x.plot(kind='bar',color=['b','r'])
plt.show()

# %%
dts.survived.value_counts().plot(kind='pie')

# %%
import seaborn as s

# seaborn use for correlation

# %%
s.countplot(x='survived',data=dts)

# %%
dts.survived.value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
s.boxplot(x='pclass',y='age',data=dts)
plt.show()

# boxplot 2 column ke bich me correlation batata hai

# %%
s.boxplot(x='pclass',y='fare',data=dts)
plt.show()

# %%
s.boxplot(x='fare',y='age',data=dts)
plt.show()

# %%
s.pairplot(data=dts)
plt.show()

# %%
s.pairplot(data=dts.dropna(axis=1))  # column ko plot karega axis 1 
#agr column me nan hai to nhi aayega use hatana padega .
plt.show()

# %% [markdown]
# pairplot sabhi ke bich me plot karega.
