# %%
import pandas as pd

# %%
dt=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data')
# dt=pd.read_csv(r'e:\ucicancer.csv')
# dt=pd.read_csv('ucicancer.csv')
dt
# Out:
#      1000025   5   1  1.1  1.2  2 1.3   3  1.4  1.5  2.1
# 0    1002945   5   4    4    5  7  10   3    2    1    2
# 1    1015425   3   1    1    1  2   2   3    1    1    2
# 2    1016277   6   8    8    1  3   4   3    7    1    2
# 3    1017023   4   1    1    3  2   1   3    1    1    2
# 4    1017122   8  10   10    8  7  10   9    7    1    4
# 5    1018099   1   1    1    1  2  10   3    1    1    2
# 6    1018561   2   1    2    1  2   1   3    1    1    2
# 7    1033078   2   1    1    1  2   1   1    1    5    2
# 8    1033078   4   2    1    1  2   1   2    1    1    2
# 9    1035283   1   1    1    1  1   1   3    1    1    2
# 10   1036172   2   1    1    1  2   1   2    1    1    2
# 11   1041801   5   3    3    3  2   3   4    4    1    4
# 12   1043999   1   1    1    1  2   3   3    1    1    2
# 13   1044572   8   7    5   10  7   9   5    5    4    4
# 14   1047630   7   4    6    4  6   1   4    3    1    4
# ...

# %%
dt.shape,dt.dtypes,dt.columns
# Out:
# ((698, 11), 1000025     int64
#  5           int64
#  1           int64
#  1.1         int64
#  1.2         int64
#  2           int64
#  1.3        object
#  3           int64
#  1.4         int64
#  1.5         int64
#  2.1         int64
#  dtype: object, Index(['1000025', '5', '1', '1.1', '1.2', '2', '1.3', '3', '1.4', '1.5',
#         '2.1'],
#        dtype='object'))

# %%
# dt.columns=list('abcdefghij')+['class']

# %%
# dt.to_csv(r'e:\ucicancer.csv')

# %%
dts=pd.read_csv('https://bit.ly/imdbratings')
# dts.to_csv('C:\Users\hp\Desktop\Cetpe M.L 22 june 2019\pandas\file.csv')

# %%
dts.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
dts[0:1]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
dts.tail(1)
# Out:
#      star_rating        title content_rating  genre  duration  \
# 978          7.4  Wall Street              R  Crime       126
#
#                                            actors_list
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...

# %%
dts.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
dts.loc[0]
dts.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
dts.shape
# Out:
# (979, 6)

# %%
dts[-1:-3:-1]
# Out:
#      star_rating        title content_rating   genre  duration  \
# 978          7.4  Wall Street              R   Crime       126
# 977          7.4  Poltergeist             PG  Horror       114
#
#                                            actors_list
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...

# %%
dts.shape
# Out:
# (979, 6)

# %%
dts.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
dts.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
dts1=pd.read_csv('https://bit.ly/imdbratings',nrows=100,usecols=[0,4,5])
dts1
# Out:
#     star_rating  duration                                        actors_list
# 0           9.3       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1           9.2       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2           9.1       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3           9.0       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4           8.9       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5           8.9        96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6           8.9       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7           8.9       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8           8.9       195  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 9           8.9       139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 10          8.8       178  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# ...

# %%
dts1.shape,dts1.columns
# Out:
# ((100, 3), Index(['star_rating', 'duration', 'actors_list'], dtype='object'))

# %%
dts.shape,dts.columns
# Out:
# ((979, 6),
#  Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#         'actors_list'],
#        dtype='object'))

# %%
x=dts['duration']>200
dts[x]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
# y=dts['genre']==

# %%
type(dts),type(x)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
x.ndim,dts.ndim
# Out:
# (1, 2)

# %%
dts[dts.duration>200]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
dts[(dts.duration>200) & ((dts.genre=='Drama')|(dts.genre=='Action'))]
# Out:
#      star_rating                            title content_rating   genre  \
# 17           8.7                    Seven Samurai        UNRATED   Drama
# 157          8.2               Gone with the Wind              G   Drama
# 476          7.8                           Hamlet          PG-13   Drama
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
dts[(dts.duration>200) & (dts.genre.isin(['Drama','Comedy','Crime']))]
# Out:
#      star_rating                        title content_rating  genre  duration  \
# 17           8.7                Seven Samurai        UNRATED  Drama       207
# 78           8.4  Once Upon a Time in America              R  Crime       229
# 157          8.2           Gone with the Wind              G  Drama       238
# 476          7.8                       Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
dts.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
dts.genre.value_counts(normalize=True)

# percentage
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Thriller     0.005107
# Sci-Fi       0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
dts[dts.genre=='Drama'].duration.describe()
# Out:
# count    278.000000
# mean     126.539568
# std       25.637086
# min       64.000000
# 25%      108.000000
# 50%      123.000000
# 75%      138.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
dts[dts.genre=='Drama'][['duration','star_rating']].agg(['count','max','min','mean'])
# Out:
#          duration  star_rating
# count  278.000000   278.000000
# max    242.000000     8.900000
# min     64.000000     7.400000
# mean   126.539568     7.902518

# %%
dts.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
dts.genre.nunique()
# Out:
# 16

# %%
for i in dts.genre.unique():
    print(i,dts[dts.genre==i]
          [['duration','star_rating']].agg(['mean']))
# Out:
# Crime         duration  star_rating
# mean  122.298387     7.916935
# Action         duration  star_rating
# mean  126.485294     7.884559
# Drama         duration  star_rating
# mean  126.539568     7.902518
# Western         duration  star_rating
# mean  136.666667     8.255556
# Adventure       duration  star_rating
# mean    134.84     7.933333
# Biography         duration  star_rating
# mean  131.844156     7.862338
# Comedy         duration  star_rating
# mean  107.602564     7.822436
# Animation        duration  star_rating
# mean  96.596774     7.914516
# Mystery       duration  star_rating
# mean   115.625        7.975
# Horror         duration  star_rating
# mean  102.517241     7.806897
# Film-Noir        duration  star_rating
# mean  97.333333     8.033333
# Sci-Fi       duration  star_rating
# mean     109.0         7.92
# History       duration  star_rating
# mean      66.0          8.0
# Thriller       duration  star_rating
# mean     114.2         7.68
# ...

# %%
dts.groupby('genre')[['duration','star_rating']].agg(['mean'])
# Out:
#              duration star_rating
#                  mean        mean
# genre
# Action     126.485294    7.884559
# Adventure  134.840000    7.933333
# Animation   96.596774    7.914516
# Biography  131.844156    7.862338
# Comedy     107.602564    7.822436
# Crime      122.298387    7.916935
# Drama      126.539568    7.902518
# Family     107.500000    7.850000
# Fantasy    112.000000    7.700000
# Film-Noir   97.333333    8.033333
# History     66.000000    8.000000
# Horror     102.517241    7.806897
# Mystery    115.625000    7.975000
# Sci-Fi     109.000000    7.920000
# Thriller   114.200000    7.680000
# Western    136.666667    8.255556

# %%
dts[dts.actors_list.str.contains('Khan')]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 89           8.4                             Swades      NOT RATED      Drama
# 93           8.4        Dilwale Dulhania Le Jayenge      NOT RATED     Comedy
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 336          8.0                         Life of Pi             PG  Adventure
# 373          8.0                    My Name Is Khan          PG-13      Drama
# 718          7.6                    The Kite Runner          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
dts.actors_list.unique()
# Out:
# array(["[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']",
#        "[u'Marlon Brando', u'Al Pacino', u'James Caan']",
#        "[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']",
#        "[u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']",
#        "[u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']",
#        "[u'Henry Fonda', u'Lee J. Cobb', u'Martin Balsam']",
#        "[u'Clint Eastwood', u'Eli Wallach', u'Lee Van Cleef']",
#        "[u'Elijah Wood', u'Viggo Mortensen', u'Ian McKellen']",
#        "[u'Liam Neeson', u'Ralph Fiennes', u'Ben Kingsley']",
#        "[u'Brad Pitt', u'Edward Norton', u'Helena Bonham Carter']",
#        "[u'Elijah Wood', u'Ian McKellen', u'Orlando Bloom']",
#        "[u'Leonardo DiCaprio', u'Joseph Gordon-Levitt', u'Ellen Page']",
#        "[u'Mark Hamill', u'Harrison Ford', u'Carrie Fisher']",
#        "[u'Tom Hanks', u'Robin Wright', u'Gary Sinise']",
#        "[u'Elijah Wood', u'Ian McKellen', u'Viggo Mortensen']",
# ...

# %%
dts.actors_list
# Out:
# 0      [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1        [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2      [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3      [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4      [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5      [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6      [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7      [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8      [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 9      [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 10     [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 11     [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 12     [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 13       [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# 14     [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 15     [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# ...

# %%
dts[0:1]['actors_list'].str.strip('[]').str.split('u')
# Out:
# 0    [, 'Tim Robbins', , 'Morgan Freeman', , 'Bob G...
# Name: actors_list, dtype: object

# %%
l=[]
for i in dts.actors_list:
    l.extend(eval(i))
set(l)
# Out:
# {'Elizabeth Berridge',
#  'Chris Evans',
#  'Claire Maurier',
#  'Michael J. Fox',
#  'Megumi Hayashibara',
#  'Vicky Haughton',
#  'Mack Swain',
#  'Kirk Douglas',
#  'Rene Auberjonois',
#  'Patricia Arquette',
#  'Akira Terao',
#  'June Squibb',
#  'Carice van Houten',
#  'Tae-hoon Kim',
#  'Omar Sharif',
#  'Kara Hayward',
#  'Hisako Kyôda',
#  'Adil Hussain',
#  'Bridgit Mendler',
#  'Martina Gedeck',
#  'Martin Sheen',
#  'Bobby Cannavale',
#  'Lee J. Cobb',
#  'Lubna Azabal',
#  'Jason Bateman',
#  "Shin'ichi Himori",
#  'Anthony Perkins',
#  'Chika Sakamoto',
#  'Christina Hendricks',
#  'Atossa Leoni',
#  'Emmanuelle Riva',
#  'Sondra Locke',
#  'Jo Hartley',
#  'Véra Clouzot',
#  'Michael Keaton',
#  'August Diehl',
#  'Diana Peñalver',
#  'Freida Pinto',
#  'Angélica Sancio',
#  'Pablo Rago',
#  'Soledad Villamil',
#  'Cybill Shepherd',
#  'Hyun-kyoon Lee',
#  'Philip Seymour Hoffman',
#  'Christopher Plummer',
#  'Madeline Kahn',
#  'Vernon Dobtcheff',
#  'Taylor Kitsch',
# ...

# %%
dts1=pd.read_csv('https://bit.ly/chiporders',sep='\t')
dts1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
# dts2=pd.read_table('https://bit.ly/chiporders')
# dts2

# %%
dts1[dts1.item_name=='Chicken Bowl'].item_name.describe()
# Out:
# count              726
# unique               1
# top       Chicken Bowl
# freq               726
# Name: item_name, dtype: object

# %%
dts1[dts1.item_name=='Chicken Bowl'][['item_name']].describe()
# Out:
#            item_name
# count            726
# unique             1
# top     Chicken Bowl
# freq             726

# %%
dts1.itemprice=dts1.item_price.str.lstrip('$')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
dts1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# dts1.item_price=dts1.item_price.astype(dtype=float)

# %%
# dts1[dts1.item_name.str.contains('Chicken')].item_price()

# %%
dts1.item_price[0:1].str.lstrip('$')
# Out:
# 0    2.39
# Name: item_price, dtype: object

# %%
dts1.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
dts3=pd.read_csv('https://bit.ly/drinksbycountry')
dts3
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
dts3.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
dts3.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
dts3
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
# dts3.set_index('country',inplace=True)

# %%
dts3.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
dts3.set_index('country',inplace=True)
# inplace=True parmanently change

# %%
dts3
# Out:
#                       beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                       0                0              0
# Albania                          89              132             54
# Algeria                          25                0             14
# Andorra                         245              138            312
# Angola                          217               57             45
# Antigua & Barbuda               102              128             45
# Argentina                       193               25            221
# Armenia                          21              179             11
# Australia                       261               72            212
# Austria                         279               75            191
# Azerbaijan                       21               46              5
# Bahamas                         122              176             51
# Bahrain                          42               63              7
# ...

# %%
dts3.reset_index('country',inplace=True)
# column ko index banana

# %%
dts3
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
dts3.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
dts3.set_index('country',inplace=True)

# %%
dts3.loc['India']
# loc for level
# Out:
# beer_servings                      9
# spirit_servings                  114
# wine_servings                      0
# total_litres_of_pure_alcohol     2.2
# continent                       Asia
# Name: India, dtype: object

# %%
dts.index
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
dts3.iloc[0]
#iloc numeric index
# Out:
# beer_servings                      0
# spirit_servings                    0
# wine_servings                      0
# total_litres_of_pure_alcohol       0
# continent                       Asia
# Name: Afghanistan, dtype: object

# %%
dts3.ix['India']
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# beer_servings                      9
# spirit_servings                  114
# wine_servings                      0
# total_litres_of_pure_alcohol     2.2
# continent                       Asia
# Name: India, dtype: object

# %%
# dts3.loc['pk']=[0,0,0,0,'APna GOla']
# dts3.loc['pk']=

# %%
dts3.tail(1)
# Out:
#           beer_servings  spirit_servings  wine_servings  \
# country
# Zimbabwe             64               18              4
#
#           total_litres_of_pure_alcohol continent
# country
# Zimbabwe                           4.7    Africa

# %%
dts3.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
dts3.reset_index(inplace=True)

# %%
dts3.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
dts3.iloc[77]
# Out:
# country                         India
# beer_servings                       9
# spirit_servings                   114
# wine_servings                       0
# total_litres_of_pure_alcohol      2.2
# continent                        Asia
# Name: 77, dtype: object

# %%
dts3.iloc[77,1]+=1

# %%
dts3.iloc[77]
# Out:
# country                         India
# beer_servings                      10
# spirit_servings                   114
# wine_servings                       0
# total_litres_of_pure_alcohol      2.2
# continent                        Asia
# Name: 77, dtype: object

# %%
dts3
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
dts3.reset_index(inplace=True)

# %%
# dts3.drop(['level_0','index'],axis=1,inplace=True)

# %%
dts3.columns
# Out:
# Index(['index', 'country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
dts3.drop([0,1,2],inplace=True)

# %%
dts3
# Out:
#      index               country  beer_servings  spirit_servings  \
# 3        3               Andorra            245              138
# 4        4                Angola            217               57
# 5        5     Antigua & Barbuda            102              128
# 6        6             Argentina            193               25
# 7        7               Armenia             21              179
# 8        8             Australia            261               72
# 9        9               Austria            279               75
# 10      10            Azerbaijan             21               46
# 11      11               Bahamas            122              176
# 12      12               Bahrain             42               63
# 13      13            Bangladesh              0                0
# 14      14              Barbados            143              173
# 15      15               Belarus            142              373
# ...

# %%
# dts.loc[0]=

# %%
dts3.sort_values(['beer_servings','spirit_servings'],ascending=[False,True])
# Out:
#      index             country  beer_servings  spirit_servings  wine_servings  \
# 117    117             Namibia            376                3              1
# 45      45      Czech Republic            361              170            134
# 62      62               Gabon            347               98             59
# 65      65             Germany            346              117            175
# 135    135              Poland            343              215             56
# 98      98           Lithuania            343              244             56
# 188    188           Venezuela            333              100              3
# 81      81             Ireland            313              118            165
# 129    129               Palau            306               63             23
# 140    140             Romania            297              122            167
# 16      16             Belgium            295               84            212
# ...

# %%
dts4=pd.read_csv('https://bit.ly/uforeports')

# %%
dts4.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
dts4.shape
# Out:
# (18241, 5)

# %%
dts4.dropna().shape
# jitne nan hai usko hta do
# Out:
# (2486, 5)

# %%
dts4.dropna(how='any').shape,dts4.dropna(how='all').shape
# any means jitne nan sabko hta do
# all means agar pure index me nan hai tab hi hatega othewise nhi.
# Out:
# ((2486, 5), (18241, 5))

# %%
dts4.fillna('kuch bhi')
# fillna used for fill data in place of nan kuch na kuch
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca        kuch bhi       TRIANGLE    NY
# 1               Willingboro        kuch bhi          OTHER    NJ
# 2                   Holyoke        kuch bhi           OVAL    CO
# 3                   Abilene        kuch bhi           DISK    KS
# 4      New York Worlds Fair        kuch bhi          LIGHT    NY
# 5               Valley City        kuch bhi           DISK    ND
# 6               Crater Lake        kuch bhi         CIRCLE    CA
# 7                      Alma        kuch bhi           DISK    MI
# 8                   Eklutna        kuch bhi          CIGAR    AK
# 9                   Hubbard        kuch bhi       CYLINDER    OR
# 10                  Fontana        kuch bhi          LIGHT    CA
# 11                 Waterloo        kuch bhi       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
dts4[dts4['Colors Reported'].isnull()]
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 13                   Keokuk             NaN           OVAL    IA
# ...

# %%
dts4[~(dts4["Colors Reported"].isnull())]
# Out:
#                     City Colors Reported Shape Reported State  \
# 12                Belton             RED         SPHERE    SC
# 19            Bering Sea             RED          OTHER    AK
# 36            Portsmouth             RED      FORMATION    VA
# 44             Blairsden           GREEN         SPHERE    CA
# 66               Wexford            BLUE            NaN    PA
# 82              San Jose            BLUE        CHEVRON    CA
# 84               Modesto            BLUE           DISK    CA
# 91                Scipio             RED         SPHERE    IN
# 111         Tarrant City          ORANGE         CIRCLE    AL
# 120              Roswell             RED            NaN    NM
# 129                 Napa           GREEN           DISK    CA
# 138        Coeur d'Alene          ORANGE          CIGAR    ID
# 152               Irving            BLUE           DISK    KS
# 157           Greenville           GREEN           DISK    MS
# ...

# %%
dts4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     15597 non-null object
# State              18241 non-null object
# Time               18241 non-null object
# dtypes: object(5)
# memory usage: 712.6+ KB

# %%
dts4.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     15597 non-null object
# State              18241 non-null object
# Time               18241 non-null object
# dtypes: object(5)
# memory usage: 5.1 MB

# %% [markdown]
# dts4.memory_usage().u
